# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/neeraj/Desktop/Neeraj/Study/Data Science/Machine Learning Udemy/UDEMY JUPYTER NOTEBOOK/TensorFlow_FILES/DATA/kc_house_data.csv')
df.head(2)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])

# %%
plt.figure(figsize=(12,8))
df['price'].hist(bins=10)

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(df['price'],df['zipcode'])

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df['price'],df['sqft_living'])

# %%
sns.scatterplot(df['bedrooms'],df['price'])

# %%
sns.boxplot(df['bedrooms'],df['price'])

# %% [markdown]
# ### How to use Lat & Longitude Feature, we will try to draw the map of King Konty
#
# As we can see at -122 Long & 47.6 lat the prices are max.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
plt.figure(figsize=(5,10))
df['price'].hist(bins=10)

# %%
df.sort_values('price',ascending=False).head(15)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %% [markdown]
# ## As we can see normally all house are in range of 4000000 USD, our top 15 homes are in range of 3.8 to 7.7 Mill USD so we can drop them to remove outliers.
#
# Hence we are dropping 15*100/21597 houses = 0.06% houses.

# %%
non_top_house = df.sort_values('price',ascending=False).iloc[16:]

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
len(df)-len(non_top_house)
# Out:
# 16

# %% [markdown]
# #### As expected we can see at -122 Long & 47.6 lat the prices are max.

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',
                data=non_top_house,hue='price',
                palette='RdYlGn',alpha=0.2)

# %%
sns.boxplot(x='waterfront',y='price',data=non_top_house)

# %%
###. Why we have not used Scatter Plot

sns.scatterplot(x='waterfront',y='price',data=non_top_house)

# %% [markdown]
# ### Feature Engineering with date

# %%
### Old Format
non_top_house['date']
# Out:
# 18467     5/11/2015
# 6502      4/21/2015
# 15241     9/11/2014
# 19133    10/11/2014
# 2862     11/18/2014
#             ...
# 2139       5/8/2014
# 8267      11/5/2014
# 16184     3/24/2015
# 465       5/23/2014
# 15279      5/6/2014
# Name: date, Length: 21581, dtype: object

# %%
non_top_house['date'] = pd.to_datetime(non_top_house['date'])

# %%
non_top_house['date']
# Out:
# 18467   2015-05-11
# 6502    2015-04-21
# 15241   2014-09-11
# 19133   2014-10-11
# 2862    2014-11-18
#            ...
# 2139    2014-05-08
# 8267    2014-11-05
# 16184   2015-03-24
# 465     2014-05-23
# 15279   2014-05-06
# Name: date, Length: 21581, dtype: datetime64[ns]

# %%
non_top_house['month'] = non_top_house['date'].apply(lambda non_top_house:non_top_house.month)

# %%
non_top_house['year'] = non_top_house['date'].apply(lambda date:date.year)

# %%
##As we can see some relation of price with month
non_top_house.groupby('month').mean()['price'].plot()

# %%
## We expect price to increase with increase in year.
non_top_house.groupby('year').mean()['price'].plot()

# %%
## Thats why are not using box plot here.
sns.boxplot(x='month',y='price',data=non_top_house)

# %%
print(sns.boxplot(x='year',y='price',data=non_top_house))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
non_top_house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
### Since there are more then 70 zipcodes, if it would have been 2/3 we would have taken pd.dummies, 
### we are removing them so that increase in zipcode is not considered at increase in price.

# %%
non_top_house.drop(['id','zipcode'],axis=1,inplace=True)

# %%
non_top_house.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# ### Why are we not taking non_top_house['Price'].values() here

# %%
X = non_top_house.drop('price',axis=1)
y = non_top_house['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
non_top_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21581 entries, 18467 to 15279
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21581 non-null  datetime64[ns]
#  1   price          21581 non-null  float64
#  2   bedrooms       21581 non-null  int64
#  3   bathrooms      21581 non-null  float64
#  4   sqft_living    21581 non-null  int64
#  5   sqft_lot       21581 non-null  int64
#  6   floors         21581 non-null  float64
#  7   waterfront     21581 non-null  int64
#  8   view           21581 non-null  int64
#  9   condition      21581 non-null  int64
#  10  grade          21581 non-null  int64
#  11  sqft_above     21581 non-null  int64
#  12  sqft_basement  21581 non-null  int64
#  13  yr_built       21581 non-null  int64
#  14  yr_renovated   21581 non-null  int64
#  15  lat            21581 non-null  float64
#  16  long           21581 non-null  float64
# ...

# %%
## 6480 is 30% of total entries of non_top_house
X_test.shape
# Out:
# (6480, 19)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam

# %%
model=Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))


model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# ### Why .values for y_train only

# %%
model.fit(X_train,y_train.values,
          validation_data=(X_test,y_test.values)
          ,batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 4ms/step - loss: 422006947840.0000 - val_loss: 288672382976.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 108825870336.0000 - val_loss: 84992262144.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 4ms/step - loss: 81525899264.0000 - val_loss: 71907540992.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 66979536896.0000 - val_loss: 58455625728.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 55864496128.0000 - val_loss: 50639405056.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 50143875072.0000 - val_loss: 46915223552.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 45820383232.0000 - val_loss: 43512934400.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
plt.figure(figsize=(12,12))
losses.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
X_test
# Out:
# array([[0.1       , 0.08      , 0.04239917, ..., 0.00887725, 0.63636364,
#         0.        ],
#        [0.3       , 0.36      , 0.17269907, ..., 0.00993734, 0.81818182,
#         0.        ],
#        [0.2       , 0.24      , 0.12512927, ..., 0.00547073, 0.90909091,
#         0.        ],
#        ...,
#        [0.1       , 0.08      , 0.05584281, ..., 0.00506255, 1.        ,
#         0.        ],
#        [0.3       , 0.2       , 0.22233713, ..., 0.00774485, 0.09090909,
#         1.        ],
#        [0.3       , 0.32      , 0.27611169, ..., 0.0196531 , 0.45454545,
#         0.        ]])

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-50e08dd7436b> in <module>
# ----> 1 mean_absolute_error(y_test,predictions)
#
# TypeError: 'tuple' object is not callable
